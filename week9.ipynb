# %%
x=int(input("x값을 입력하세요:"))
y=x*x*3+5*x+3
print("결과 y값은",y,"입니다.")
# Out:
# x값을 입력하세요:3
# 결과 y값은 45 입니다.

# %%
x=int(input("반지름을 입력하세요:"))
print("원의 둘레는",2*x*3.14,"입니다.")
print("원의 넓이는",x*x*3.14,"입니다.")
# Out:
# 반지름을 입력하세요:5
# 원의 둘레는 31.400000000000002 입니다.
# 원의 넓이는 78.5 입니다.
