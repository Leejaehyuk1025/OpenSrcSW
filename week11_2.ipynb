# %%
#실습 8. 사칙 연산 클래스
import import_ipynb

# %%
from week11_class import Calc
# Out:
# importing Jupyter notebook from week11_class.ipynb

# %%
calc=Calc()

# %%
calc.sum(3,3)
calc.sub(3,3)
calc.mul(3,3)
calc.div(3,3)
# Out:
# 3.000 + 3.000 = 6.000 입니다
# 3.000 - 3.000 = 0.000 입니다
# 3.000 * 3.000 = 9.000 입니다
# 3.000 / 3.000 = 1.000 입니다
